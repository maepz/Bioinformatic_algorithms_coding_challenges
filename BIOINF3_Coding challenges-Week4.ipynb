# %%
''' Implement GreedySorting. '''
'''
GreedySorting(P)
        approxReversalDistance ← 0
        for k = 1 to |P|
            if element k is not sorted
                apply the k-sorting reversal to P
                approxReversalDistance ← approxReversalDistance + 1
            if k-th element of P is −k
                apply the k-sorting reversal to P
                approxReversalDistance ← approxReversalDistance + 1
        return approxReversalDistance
'''
def neg(n):
    return n*-1

def printplus(n):
    return "%+d" % n

def GreedySorting(P):
    approxReversalDistance=0
    for k in range(1,len(P)):
        #print k,P[k],range(len(P))[k]
        if P[k] != range(len(P))[k]:
            posig=map(abs,P).index(k)
            #print posig
            #print P[0:k],map(neg,P[posig:k-1:-1]),P[posig+1:]
            P=P[0:k]+map(neg,P[posig:k-1:-1])+P[posig+1:]
            approxReversalDistance+=1
            withplus=map(printplus,P[1:len(P)-1])
            print '('+' '.join(map(str,withplus))+')'
        if P[k] == neg(range(len(P))[k]):
            P=P[:k]+[neg(P[k])]+P[k+1:]
            approxReversalDistance+=1
            withplus=map(printplus,P[1:len(P)-1])
            print '('+' '.join(map(str,withplus))+')'
            
    return approxReversalDistance
### test 1 ###
'''
P='(-3 +4 +1 +5 -2)'
P='0 '+P[1:-1]
P=map(int,P.split(' '))
P=P+[len(P)]
#print range(len(P))
#print len(P)
#print P

'''
### test 2 ###
'''
f=open('input.txt','r')
lines=f.read().splitlines()
f.close()
P=str(lines[0])
P='0 '+P[1:-1]
P=map(int,P.split(' '))
P=P+[len(P)]
'''
### quizz ###

#P='(-16 -20 +12 +18 -14 -17 -15 -6 -8 -19 -11 +13 -10 +4 -5 -2 +7 -3 +1 -9)'
### challenge ###

#f=open('../../Downloads/dataset_286_4.txt','r')
f=open('../../Downloads/rosalind_ba6a.txt','r')
lines=f.read().splitlines()
f.close()
P=str(lines[0])


P='0 '+P[1:-1]
P=map(int,P.split(' '))
P=P+[len(P)]

###
print GreedySorting(P)
# Out:
# (-1 -107 -52 +111 -14 -97 +55 +56 +112 -127 +117 +90 +126 -118 +115 -91 -25 -94 -83 +23 -129 -69 +21 +63 -80 +125 -116 +15 -81 +11 +2 -7 -43 -40 -13 +113 -65 +124 -130 +29 +82 -6 +96 +66 -64 -45 +30 +19 -61 -36 -51 +59 -93 +17 +119 +50 -3 -123 +73 +72 +44 +87 +103 -5 +102 +104 +75 -89 -48 -78 +88 -8 +62 +68 +24 -46 +92 +106 -34 +53 -120 -18 -101 -110 -71 -108 +114 +37 +39 +98 +26 +32 +84 -79 -105 -100 -134 -77 +122 -99 +74 +38 +27 +49 +109 -47 -31 -57 -16 -70 -76 -85 -9 -42 -20 +4 -28 +131 -132 +95 +54 +121 +67 -41 +86 -35 +12 +10 +22 -60 -33 -128 +133 -58)
# ...

# %%
''' Find the number of breakpoints in a permutation.'''

def Breakpoints(P):
    bp=0
    P='0 '+P[1:-1]
    P=map(int,P.split(' '))
    P=P+[len(P)]
    for k in range(len(P)-1):
        #print P[k],P[k+1]
        if (P[k+1]>0 and P[k+1] == P[k]+1) or (P[k+1]<0 and P[k+1]-1 == P[k]):
            continue
        else:    
            bp+=1
    return bp

### test 1 ###
#P='(+3 +4 +5 -12 -8 -7 -6 +1 +2 +10 +9 -11 +13 +14)'

### test 2 ###
'''
f=open('input.txt','r')
lines=f.read().splitlines()
f.close()
P=str(lines[0])
'''

### quizz ###
#P='(+6 -12 -9 +17 +18 -4 +5 -3 +11 +19 +20 +10 +8 +15 -14 -13 +2 +7 -16 -1)'


### challenge ###

#f=open('../../Downloads/dataset_287_6.txt','r')
f=open('../../Downloads/rosalind_ba6b.txt','r')
lines=f.read().splitlines()
f.close()
P=str(lines[0])

print Breakpoints(P)
# Out:
# 98
