# %%
from Bioinf_functions import *
dir()
# Out:
# ['ALLOW_THREADS',
#  'ApproximatePatternCount',
#  'ApproximatePatternMatch',
#  'BUFSIZE',
#  'Bioinf_functions',
#  'CLIP',
#  'ClumpFind',
#  'ComplexWarning',
#  'Consensus',
#  'DataSource',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'FindingFrequentWordsBySorting',
#  'FrequencyArray',
#  'FrequentWords',
#  'FrequentWordsWithMismatches',
#  'GIBBSSAMPLER',
#  'GREEDYMOTIFSEARCH',
#  'GetFuncViaStr',
#  'HammingDistance',
#  'ImmediateNeighbors',
#  'In',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MEDIANSTRING',
#  'MOTIFENUMERATION',
#  'MachAr',
#  'MakeProfile',
#  'MakeProfileRaw',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'Neighbors',
#  'NumberToPattern',
#  'Out',
#  'PINF',
#  'PZERO',
#  'PackageLoader',
#  'PatternCount',
#  'PatternMatch',
# ...

# %%
'''Reconstructing strings from k-mers

We are now ready to define a computational problem modeling genome assembly. Given a string Text, its k-mer composition Compositionk(Text) is the collection of all k-mer substrings of Text (including repeated k-mers). For example,

Composition3(TATGGGGTGC) = {ATG, GGG, GGG, GGT, GTG, TAT, TGC, TGG}
Note that we have listed k-mers in lexicographic order (i.e., how they would appear in a dictionary) rather than in the order of their appearance in TATGGGGTGC. We have done this because the correct ordering of the reads is unknown when they are generated.

String Composition Problem: Generate the k-mer composition of a string.
     Input: An integer k and a string Text.
     Output: Compositionk(Text), where the k-mers are arranged in lexicographic order.'''


'''RAW'''

k=5
word='CAATCCAAC'

#print k,word
i=0
liste=[]
while i < len(word)-(k-1):
    kmer=word[i:i+k]
    liste.append(kmer)
    i+=1
#print liste    
print("\n".join(map(str,liste)))

''' Function '''

def KmerList(word,k):
    i=0
    liste=[]
    while i < len(word)-(k-1):
        kmer=word[i:i+k]
        liste.append(kmer)
        i+=1
    liste.sort()
    return (liste)

print '\n'.join(KmerList('CAATCCAAC',5))

''' Challenge answer '''

f=open('../../Downloads/rosalind_ba3a.txt','r')
lines=f.read().splitlines()
f.close()
k=int(lines[0])
word=str(lines[1])
fa=open('answer.txt','w')
fa.write('\n'.join(KmerList(word,k)))
fa.close()
print '\n'.join(KmerList(word,k))
# Out:
# 'Reconstructing strings from k-mers\n\nWe are now ready to define a computational problem modeling genome assembly. Given a string Text, its k-mer composition Compositionk(Text) is the collection of all k-mer substrings of Text (including repeated k-mers). For example,\n\nComposition3(TATGGGGTGC) = {ATG, GGG, GGG, GGT, GTG, TAT, TGC, TGG}\nNote that we have listed k-mers in lexicographic order (i.e., how they would appear in a dictionary) rather than in the order of their appearance in TATGGGGTGC. We have done this because the correct ordering of the reads is unknown when they are generated.\n\nString Composition Problem: Generate the k-mer composition of a string.\n     Input: An integer k and a string Text.\n     Output: Compositionk(Text), where the k-mers are arranged in lexicographic order.'

# %%
'''String Spelled by a Genome Path Problem. Reconstruct a string from its genome path.
     Input: A sequence of k-mers Pattern1, … ,Patternn such that the last k - 1 symbols of Patterni are
                equal to the first k-1 symbols of Patterni+1 for 1 ≤ i ≤ n-1.
     Output: A string Text of length k+n-1 such that the i-th k-mer in Text is equal to Patterni  (for 1 ≤ i ≤ n).'''

'''RAW''' 

path='ACCGA','CCGAA','CGAAG','GAAGC','AAGCT'
for n in range(0,len(path)):
    #print path[n]
    #print path[n][1:len(path[n])] , path[n+1][:-1], path[n+1][len(path[n+1])-1:], (len(seq))
    if n==0:
        seq=path[n]
        #print seq
    else:    
        #print seq[-(len(path[n])-1):]
        if seq[-(len(path[n])-1):] ==  path[n][:-1]:
            #print seq, path[n]
            
            seq+=path[n][-1]
print seq            
        

''' FUNCTION '''

''' MY CODE '''
def GenomePath2String(path):
    for n in range(0,len(path)):
        if n==0:
            seq=path[n]
        else:    
            if seq[-(len(path[n])-1):] ==  path[n][:-1]:
                seq+=path[n][-1]
    return seq  

''' ROSALIND CODE '''

def GenomePath2String(path):
    return path[0] + ''.join([item[-1] for item in path[1:]])

print GenomePath2String(path)

''' CHALLENGE '''

f=open('../../Downloads/dataset_198_3.txt','r')
lines=f.read().splitlines()
print lines[:5]
f.close()
path=lines[:]
fa=open('answer.txt','w')
fa.write(GenomePath2String(path))
fa.close()
''' USING prefix and suffix '''
word='ATGC'
path='ACCGA','CCGAA','CGAAG','GAAGC','AAGCT'

def Prefix(word):
    return word[:-1]
def Suffix(word):
    return word[1:]

print Prefix(word), Suffix(word)

def GenomePath2String(path):
    seq=path[0]
    for n in range(1,len(path)):   
        if Prefix(path[n]) ==  Suffix(path[n-1]):
                seq+=path[n][-1]
    return seq  
GenomePath2String(path)
# Out:
# ACCGAAGCT

# %%
'''To generalize the construction of the above graph to an arbitrary collection of k-mers Patterns, we form a node for each k-mer in Patterns and connect k-mers Pattern and Pattern' by a directed edge if Suffix(Pattern) is equal to Prefix(Pattern'). The resulting graph is called the overlap graph on these k-mers, denoted Overlap(Patterns).

Overlap Graph Problem: Construct the overlap graph of a collection of k-mers.
     Input: A collection Patterns of k-mers.
     Output: The overlap graph Overlap(Patterns).'''

''' RAW '''

def Prefix(word):
    return word[:-1]
def Suffix(word):
    return word[1:]

words=['ATGCG','GCATG','CATGC','AGGCA','GGCAT']
words.sort()

liste=[]
for n in range(0,len(words)):
    inv_word=words[n]
    for kmer in words:
        if Suffix(inv_word)== Prefix(kmer):
            liste.append(str(inv_word)+' -> '+str(kmer))
#print '\n'.join(liste)  

''' USING DICTIONARIES '''

'''pref={}
suff={}
liste=[]
for word in words:
    pref[Prefix(word)]=word #problem in multiple words have same prefix
    suff[Suffix(word)]=word
for word in words:
    if Suffix(word) in pref.keys():
        print word+' -> '+pref[Suffix(word)]'''
        
''' FUNCTION '''

def Overlap(Patterns):
    from collections import defaultdict
    pref={}
    suff={}
    liste=[]
    for word in Patterns:
        pref[Prefix(word)]=word #problem in multiple words have same prefix
        suff[Suffix(word)]=word
    for word in Patterns:
        if Suffix(word) in pref.keys():
            liste.append(word+' -> '+pref[Suffix(word)])
    return liste        

#print '\n'.join(Overlap(words))

''' Function multiple prefix '''
def Prefix(word):
    return word[:-1]

def Suffix(word):
    return word[1:]

def Overlap(Patterns):
    from collections import defaultdict
    pref=defaultdict(list)
    suff=defaultdict(list)
    liste=[]
    for word in Patterns:
        pref[Prefix(word)].append(word)
        suff[Suffix(word)].append(word)
    for word in Patterns:
        if Suffix(word) in pref.keys():
            for item in pref[Suffix(word)]:
                liste.append(word+' -> '+item)
    return liste        

print '\n'.join(Overlap(words))

''' ROSALIND ANSWER '''

from collections import defaultdict

def formatGraph(graph):
    lines = []
    for source in sorted(graph):
        for target in sorted(graph[source]):
            lines.append("%s -> %s" % (source, target))
    return ("\n").join(lines)

def OverlapGraph(nodes):
    # 1. group target nodes by prefix
    targets = defaultdict(list)
    for node in nodes:
        prefix = node[:-1]
        targets[prefix].append(node)
    # 2. map target nodes to postfix
    graph = {}
    for node in nodes:
        postfix = node[1:]
        if postfix in targets:
            graph[node] = targets[postfix]
    return graph

#print formatGraph(OverlapGraph(words))

''' CHALLENGE '''

f=open('../../Downloads/dataset_198_9.txt','r')
lines=f.read().splitlines()
f.close()
Patterns=lines[:]
#print Patterns[:5]
#print '\n'.join(Overlap(Patterns))  

fa=open('answer.txt','w')
fa.write('\n'.join(Overlap(Patterns)))
fa.close()
# Out:
# AGGCA -> GGCAT
# CATGC -> ATGCG
# GCATG -> CATGC
# GGCAT -> GCATG

# %%
''' EXERCISE BREAK: Construct a 4-universal string.
Unsucessful'''

print 2**4
def NumberToPattern(Number, k):
    d={'0':0,'1':1}
    pattern=[]
    if k==1:
        #return d.keys()[d.values().index(Number)]
        return (list(d.keys())[list(d.values()).index(int(Number))])
    prefixIndex = Number//2
    r = Number%2
    PrefixPattern = NumberToPattern(prefixIndex, (k-1))
    symbol = (list(d.keys())[list(d.values()).index(r)])
    return (PrefixPattern+symbol)

k=4
Patterns=[]
for number in range(0,2**k):
    Patterns.append(NumberToPattern(number, k))
print Patterns    


def Overlap(Patterns):
    from collections import defaultdict
    pref=defaultdict(list)
    suff=defaultdict(list)
    liste=[]
    for word in Patterns:
        pref[Prefix(word)].append(word)
        suff[Suffix(word)].append(word)
    for word in Patterns:
        if Suffix(word) in pref.keys():
            for item in pref[Suffix(word)]:
                if item != word:
                    liste.append(word+' -> '+item)
    return liste        

print '\n'.join(Overlap(Patterns))

## make de_bruijn for alphabet (found online)
def de_bruijn(k, n):
    """
    De Bruijn sequence for alphabet k
    and subsequences of length n.
    """
    try:
        # let's see if k can be cast to an integer;
        # if so, make our alphabet a list
        _ = int(k)
        alphabet = list(map(str, range(k)))

    except (ValueError, TypeError):
        alphabet = k
        k = len(k)

    a = [0] * k * n
    sequence = []

    def db(t, p):
        if t > n:
            if n % p == 0:
                sequence.extend(a[1:p + 1])
        else:
            a[t] = a[t - p]
            db(t + 1, p)
            for j in range(a[t - p] + 1, k):
                a[t] = j
                db(t + 1, t)
    db(1, 1)
    return "".join(alphabet[i] for i in sequence)

print(de_bruijn('01', 4))
# Out:
# 16

# %%
'''  Solve the De Bruijn Graph from a String Problem.
     Input: An integer k and a string Text.
     Output: DeBruijnk(Text), in the form of an adjacency list.'''

''' RAW '''

k=4
Text='AAGATTCTCTAAGA'

Patterns=KmerList(Text,k)
#print Patterns

def Prefix(word):
    return word[:-1]

def Suffix(word):
    return word[1:]


from collections import defaultdict
pref={}
suff={}
link=defaultdict(list)
liste=[]
for word in Patterns:
    #print Prefix(word), Suffix(word)
    pref[word]=Prefix(word)
    suff[word]=Suffix(word)
for word in Patterns:
    if word in pref.keys():
        link[pref[word]].append(suff[word])
print [str(key)+' -> '+str(','.join(value)) for key,value in link.items()]

#print liste        
#print pref.keys(),suff.keys()
#print '\n'.join(Overlap(Patterns))

''' FUNCTION '''

def KmerList(word,k):
    i=0
    liste=[]
    while i < len(word)-(k-1):
        kmer=word[i:i+k]
        liste.append(kmer)
        i+=1
    liste.sort()
    return (liste)

def DeBruijn_k(Patterns,k):
    from collections import defaultdict
    from collections import OrderedDict
    
    def Prefix(word):
        return word[:-1]

    def Suffix(word):
        return word[1:]
    
    pref={}
    suff={}
    link=defaultdict(list)
    liste=[]
    for word in Patterns:
        pref[word]=Prefix(word)
        suff[word]=Suffix(word)
    for word in Patterns:
        if word in sorted(pref):
            link[pref[word]].append(suff[word])      
    return [str(key)+' -> '+str(','.join(value)) for key,value in sorted(link.items())]

print '\n'.join(DeBruijn_k(KmerList(Text,k),k))


''' CHALLENGE '''
#k=4
#Text='AAGATTCTCTAAGA'

f=open('../../Downloads/dataset_199_6.txt','r')
lines=f.read().splitlines()
f.close()
k=int(lines[0])
Text=str(lines[1])
#print Patterns[:5]


fa=open('answer.txt','w')
fa.write('\n'.join(DeBruijn_k(KmerList(Text,k),k)))
fa.close()

''' ROSALIND '''

def kmer_generator(dna, kmer_size):
    position = 0
    while(position+kmer_size <= len(dna)):
        yield dna[position:position+kmer_size]
        position += 1

def de_bruijn(dna, size):
    result = {}
    kmers = [m for m in kmer_generator(dna, size-1)]
    for i in range(len(kmers)-1):
        try:
            result[kmers[i]].append(kmers[i+1])
        except KeyError:
            result[kmers[i]] = [kmers[i+1]]
    return result

m = de_bruijn("AAGATTCTCTAC", 4)

with open("output.txt", "w") as f:
    for key in m:
        f.write(key + " -> " + ','.join([v for v in m[key]]) + "\n")
# Out:
# ['AAG -> AGA,AGA', 'TCT -> CTA,CTC', 'GAT -> ATT', 'AGA -> GAT', 'ATT -> TTC', 'CTA -> TAA', 'CTC -> TCT', 'TTC -> TCT', 'TAA -> AAG']
# AAG -> AGA,AGA
# AGA -> GAT
# ATT -> TTC
# CTA -> TAA
# CTC -> TCT
# GAT -> ATT
# TAA -> AAG
# TCT -> CTA,CTC
# TTC -> TCT

# %%
'''
1. If we gave you the de Bruijn graph DeBruijnk(Text) without giving you Text, could you reconstruct Text?
2. Construct the de Bruijn graphs DeBruijn2(TAATGCCATGGGATGTT), DeBruijn3(TAATGCCATGGGATGTT), 
and DeBruijn4(TAATGCCATGGGATGTT). What do you notice?
3. How does the graph DeBruijn3(TAATGCCATGGGATGTT) compare to DeBruijn3(TAATGGGATGCCATGTT)?'''

print len(DeBruijn_k(KmerList('TAATGCCATGGGATGTT',2),2))
print len(DeBruijn_k(KmerList('TAATGCCATGGGATGTT',3),3))
print len(DeBruijn_k(KmerList('TAATGCCATGGGATGTT',4),4))
print (DeBruijn_k(KmerList('TAATGCCATGGGATGTT',3),3))
print (DeBruijn_k(KmerList('TAATGGGATGCCATGTT',3),3))
# Out:
# 4

# %%
''' DeBruijn Graph from k-mers Problem: Construct the de Bruijn graph from a set of k-mers.
     Input: A collection of k-mers Patterns.
     Output: The adjacency list of the de Bruijn graph DeBruijn(Patterns).

'''

''' RAW '''

Patterns='GAGG','CAGG','GGGG','GGGA','CAGG','AGGG','GGAG'
k=len(Pattern[0])
print(Pattern, k)


print '\n'.join(DeBruijn_k(Patterns,k))

''' FUNCTION '''

''' CHALLENGE '''

f=open('../../Downloads/rosalind_ba3e (1).txt','r')
lines=f.read().splitlines()
f.close()
k=len(lines[0])
Pattern=lines

fa=open('answer.txt','w')
fa.write('\n'.join(DeBruijn_k(Pattern,k)))
fa.close()
# Out:
# (['CCAGCTACGACTGAAATGAA', 'GGAGCACCCGTGAAGGACAA', 'GGCAACGGGCTCTTATTTCT', 'TACGCGCTTCGGGTGCGCGG', 'AGGGGCGGTCGGTGCCTGAC', 'ACAGCACACAAGCATTGGCT', 'TTAAAGTAATCCCCTAGCCA', 'GAGGTAAGGTTTGAATAATT', 'CGAGCGGGAAGCTTCGAATA', 'AAGCCTAAGCACCCGTACTG', 'ACTTACTATAAGGAGATTGT', 'CGCTAGGAATGTCCGATGCC', 'CAACCACACCCGGAGACATC', 'TCTAGGCTAGACGGCGTCGT', 'CATGTCATGCCTAGATTGCG', 'GAAGCTCCTGCTAGGCGATA', 'CCGATACCGAAGATTGTTAG', 'AAACTACAGCTTTTCGGAGT', 'CTGAATCGATTACTGCCGAT', 'GCCTGACTTGTTCGCACCTA', 'CTATATCCCAATCGGGCTTA', 'TCTAGAGGTAGACGCCCACC', 'CATTAATTCCCCGAAGCTTG', 'AGCTCTTATCATGCCTGAGC', 'GGTTTCTTTTGGCTTGATAA', 'AGCAAATCAGCCGACCGGAC', 'GCGCGGCGTATTGCCTAAGG', 'GATTGAAACCAAAAGAGGTA', 'CGGCAGAATTTTCTATATCC', 'ACCGATTGAAACCAAAAGAG', 'GTCTAACACGTCGTGTGTCC', 'CGTATTTTTTAGCGCTAGGA', 'AAAGCCGATGGGTCCGCTCG', 'AGCTTCGAATAGAGTCCGCG', 'TCCGATACCGAAGATTGTGT', 'GTACACAATAGGCGTATTTT', 'TGGCGATATCTTGACAACAG', 'ATGAAACTTTACAAAACTGG', 'GGGTGCGCGGCGTATTGCCT', 'GCCGATGGGTCCGCTCGGTC', 'GTAGCTTCAAACGATGTTTT', 'CAGCTTACGGC
# ...
